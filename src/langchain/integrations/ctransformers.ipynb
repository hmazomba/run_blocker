# %%
from langchain.llms import CTransformers

model_path="../../../../../Models/LLMs/GGML/llama-2-7b-chat.ggmlv3.q8_0.bin"
llama_llm = CTransformers(model=model_path, model_type='llama')

# %%
from langchain import PromptTemplate, LLMChain

template = """Question: {question}

Answer:"""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

response = llm_chain.run("What is AI?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       7 prompt = PromptTemplate(template=template, input_variables=["question"])
#       9 llm_chain = LLMChain(prompt=prompt, llm=llm)
# ---> 11 response = llm_chain.run("What is AI?")
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/chains/base.py:440, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     438     if len(args) != 1:
#     439         raise ValueError("`run` supports only one positional argument.")
# --> 440     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     441         _output_key
#     442     ]
#     444 if kwargs and not args:
#     445     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     446         _output_key
#     447     ]
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/chains/base.py:243, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
# --> 243     raise e
#     244 run_manager.on_chain_end(outputs)
#     245 final_outputs: Dict[str, Any] = self.prep_outputs(
#     246     inputs, outputs, return_only_outputs
#     247 )
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/chains/base.py:237, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     231 run_manager = callback_manager.on_chain_start(
#     232     dumpd(self),
#     233     inputs,
#     234 )
#     235 try:
#     236     outputs = (
# --> 237         self._call(inputs, run_manager=run_manager)
#     238         if new_arg_supported
#     239         else self._call(inputs)
#     240     )
#     241 except (KeyboardInterrupt, Exception) as e:
#     242     run_manager.on_chain_error(e)
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/chains/llm.py:92, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
# ---> 92     response = self.generate([inputs], run_manager=run_manager)
#      93     return self.create_outputs(response)[0]
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/chains/llm.py:102, in LLMChain.generate(self, input_list, run_manager)
#     100 """Generate LLM result from inputs."""
#     101 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102 return self.llm.generate_prompt(
#     103     prompts,
#     104     stop,
#     105     callbacks=run_manager.get_child() if run_manager else None,
#     106     **self.llm_kwargs,
#     107 )
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/base.py:186, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     178 def generate_prompt(
#     179     self,
#     180     prompts: List[PromptValue],
#    (...)
#     183     **kwargs: Any,
#     184 ) -> LLMResult:
#     185     prompt_strings = [p.to_string() for p in prompts]
# --> 186     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/base.py:279, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, **kwargs)
#     273         raise ValueError(
#     274             "Asked to cache, but no cache found at `langchain.cache`."
#     275         )
#     276     run_managers = callback_manager.on_llm_start(
#     277         dumpd(self), prompts, invocation_params=params, options=options
#     278     )
# --> 279     output = self._generate_helper(
#     280         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     281     )
#     282     return output
#     283 if len(missing_prompts) > 0:
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/base.py:223, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     221     for run_manager in run_managers:
#     222         run_manager.on_llm_error(e)
# --> 223     raise e
#     224 flattened_outputs = output.flatten()
#     225 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/base.py:210, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     200 def _generate_helper(
#     201     self,
#     202     prompts: List[str],
#    (...)
#     206     **kwargs: Any,
#     207 ) -> LLMResult:
#     208     try:
#     209         output = (
# --> 210             self._generate(
#     211                 prompts,
#     212                 stop=stop,
#     213                 # TODO: support multiple run managers
#     214                 run_manager=run_managers[0] if run_managers else None,
#     215                 **kwargs,
#     216             )
#     217             if new_arg_supported
#     218             else self._generate(prompts, stop=stop)
#     219         )
#     220     except (KeyboardInterrupt, Exception) as e:
#     221         for run_manager in run_managers:
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/base.py:602, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#     599 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#     600 for prompt in prompts:
#     601     text = (
# --> 602         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#     603         if new_arg_supported
#     604         else self._call(prompt, stop=stop, **kwargs)
#     605     )
#     606     generations.append([Generation(text=text)])
#     607 return LLMResult(generations=generations)
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/langchain/llms/ctransformers.py:106, in CTransformers._call(self, prompt, stop, run_manager, **kwargs)
#     104 text = []
#     105 _run_manager = run_manager or CallbackManagerForLLMRun.get_noop_manager()
# --> 106 for chunk in self.client(prompt, stop=stop, stream=True):
#     107     text.append(chunk)
#     108     _run_manager.on_llm_new_token(chunk, verbose=self.verbose)
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/ctransformers/llm.py:465, in LLM._stream(self, prompt, max_new_tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, stop, reset)
#     463 text = ""
#     464 incomplete = b""
# --> 465 for token in self.generate(
#     466     tokens,
#     467     top_k=top_k,
#     468     top_p=top_p,
#     469     temperature=temperature,
#     470     repetition_penalty=repetition_penalty,
#     471     last_n_tokens=last_n_tokens,
#     472     seed=seed,
#     473     batch_size=batch_size,
#     474     threads=threads,
#     475     reset=reset,
#     476 ):
#     477     # Handle incomplete UTF-8 multi-byte characters.
#     478     incomplete += self.detokenize([token], decode=False)
#     479     complete, incomplete = utf8_split_incomplete(incomplete)
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/ctransformers/llm.py:432, in LLM.generate(self, tokens, top_k, top_p, temperature, repetition_penalty, last_n_tokens, seed, batch_size, threads, reset)
#     423 while True:
#     424     token = self.sample(
#     425         top_k=top_k,
#     426         top_p=top_p,
#    (...)
#     430         seed=seed,
#     431     )
# --> 432     self.eval([token], batch_size=batch_size, threads=threads)
#     433     if self.is_eos_token(token):
#     434         break
#
# File ~/.conda/envs/cedric/lib/python3.10/site-packages/ctransformers/llm.py:339, in LLM.eval(self, tokens, batch_size, threads)
#     337 n_tokens = len(tokens)
#     338 tokens = (c_int * n_tokens)(*tokens)
# --> 339 status = self.ctransformers_llm_batch_eval(
#     340     tokens,
#     341     n_tokens,
#     342     batch_size,
#     343     threads,
#     344 )
#     345 if not status:
#     346     raise RuntimeError("Failed to evaluate tokens.")
#
# KeyboardInterrupt:
