# %%
import requests
import json

# %%
# Replace 'YOUR_ACCESS_TOKEN' with your actual access token or private app access token
access_token = 'pat-na1-1de21061-6a6d-4a90-8e39-28a0735c0325'

# Replace 'YOUR_FORM_GUID' with the GUID of the form you want to retrieve submissions from
form_guid = 'c2c468a3-9304-4f02-a1d6-53985691bcff'

# Set the API endpoint URL
url = f'https://api.hubapi.com/form-integrations/v1/submissions/forms/{form_guid}'

# %%
headers = {
    'Authorization': f'Bearer {access_token}',
    'User-Agent': 'eCommerce Submissions'
}

params = {
    'limit': 30  # Optional: Adjust the limit parameter as needed
}

# %%
response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    data = response.json()
    # Process the retrieved data as needed
    print(json.dumps(data, indent=4))  # Example: Print the response in JSON format
else:
    print(f'Request failed with status code {response.status_code}')
# Out:
# {
#     "results": [
#         {
#             "submittedAt": 1687087967753,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "shubhdeepaulakh078@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Navdeep kaur",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Surwind",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Punjab",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Surwind tarn taran",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Surwind",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "8284829838",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "No",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "Introduction to Cyber Security",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=kwd-0&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=Cj0KCQjw1rqkBhCTARIsAAHz7K2P7iEY2Sq65upOWjA8r_s1svNLQiyXWrt_Vv8_5r9Jv9iLwat4T4saAiqTEALw_wcB"
#         },
#         {
#             "submittedAt": 1687073588664,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "shikharsapkota453@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Shikhar sapkota",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Arlangkot",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Gulmi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Critike",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Nepal",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "9861640064",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CISM OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=Cj0KCQjw1rqkBhCTARIsAAHz7K3_EXKnx2nkvX7MjN09_Vho_3X68Wz_CDThfDb7KNTK7CbMCr_1Nw4aArq9EALw_wcB"
#         },
#         {
#             "submittedAt": 1686892964188,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "ahkik2544@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Ahki Khatun",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "\u099d\u09bf\u0995\u09b0\u0997\u09be\u099b\u09be, \u09ab\u09c1\u09b2\u09ac\u09be\u09dc\u09bf \u09af\u09b6\u09cb\u09b0",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "\u0997\u09cd\u09b0\u09be\u09ae",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "\u09ac\u09be\u0982\u09b2\u09be\u09a6\u09c7\u09b6",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "\u09af\u09b6\u09cb\u09b0",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "01307527964",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "\u09a6\u09bf\u09b6\u09be \u0996\u09be\u09a4\u09c1\u09a8",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CompTIA Network+",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=network%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=kwd-11103501&hsa_kw=network%20security%20training&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIt9udx_7G_wIV__xMAh0E3ABfEAEYASAAEgLIYPD_BwE"
#         },
#         {
#             "submittedAt": 1686892488534,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "ahkik2544@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Dsiha khatun",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Jigar ghaza  FullBari",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Bangladesh",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "\u0997\u09cd\u09b0\u09be\u09ae",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Jessore",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "01307527964",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "ahkik254@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CompTIA Network+",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=network%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=kwd-11103501&hsa_kw=network%20security%20training&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIt9udx_7G_wIV__xMAh0E3ABfEAEYASAAEgLIYPD_BwE"
#         },
#         {
#             "submittedAt": 1686682191634,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "mokhethimohale01@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Mokhethi piet",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "1558 b serobele street",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Johannesburg",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "D14",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "South Africa",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0748404541",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "None",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CISM OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses"
#         },
#         {
#             "submittedAt": 1686626747627,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "morzinakhatun995@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Abu",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Dubai",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Dubai",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Mu",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Dubai",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "01920704842",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "Mu",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CISM OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=kwd-0&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIgsPi3aW__wIVQ8OPCh2V3A5eEAEYASAAEgJZx_D_BwE"
#         },
#         {
#             "submittedAt": 1686041584298,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "kgetjam@sasria.co.za",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Kgetja Bruce Mphekgwane",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "373 Xaba",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Katlehong",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Gauteng",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "South Africa",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0659210180",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "SASRIA",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "CompTIA Security+ 601",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=instagram&utm_medium=social&utm_content=Cybersecurity%20Organic%20Posts"
#         },
#         {
#             "submittedAt": 1686030334865,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "sppaul151@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "sujoy paul",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Dhaka, Dhaka",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Dhaka",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Dhanmondi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Bangladesh",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "01314989976",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "student",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=d&hsa_tgt=kwd-0&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI97edg_it_wIVSRHVCh3B9gw7EAEYASAAEgL3R_D_BwE"
#         },
#         {
#             "submittedAt": 1685641719975,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "rajputsonu4093@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Abhishek rajput",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "id_number",
#                     "value": "63",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Runi chursai",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Farrukhabad",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Up",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Up",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "6386683239",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "Electric",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20security%20and%20hacking&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=g&hsa_tgt=kwd-86415059336&hsa_kw=cyber%20security%20and%20hacking&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAjwg-GjBhBnEiwAMUvNW06PWWFo2fbF1GAXCTuPOrMHllpledJcBjBksQw2A5IusWnbaCfZ9BoC8jgQAvD_BwE"
#         },
#         {
#             "submittedAt": 1685639354097,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "khubaibzubairy@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "khubaib mahmood zubairi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "id_number",
#                     "value": "+923216520225",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "H63 mohallah rasool park model town lhr",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Lajore",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Pujab",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Pakistan",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "03216520225",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "khubaib",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20course&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-124723537&hsa_kw=cyber%20course&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIupLvpMWi_wIVCcjVCh2txwAcEAAYAyAAEgJC-PD_BwE"
#         },
#         {
#             "submittedAt": 1685639237680,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "khubaibzubairy@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "khubaib mahmood zubairi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "id_number",
#                     "value": "+923216520225",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "H63 mohallah rasool park model town lhr",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Lajore",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Pujab",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Pakistan",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "03216520225",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CompTIA Network+",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "South African Rand",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20course&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-124723537&hsa_kw=cyber%20course&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIupLvpMWi_wIVCcjVCh2txwAcEAAYAyAAEgJC-PD_BwE"
#         },
#         {
#             "submittedAt": 1685633252116,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "abdulnasirsadat66@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Abdul Nasir",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "id_number",
#                     "value": "1399090131942",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "62",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Jalalabad",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Islam",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Afghanistan",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0730914766",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20security&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=g&hsa_tgt=kwd-14868266&hsa_kw=cyber%20security&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAjwg-GjBhBnEiwAMUvNW3qDae5OnSBVQ344l_6IzOd6xwDTL3qGMIuOZL3XS42Abt9WGO_vHBoCLtsQAvD_BwE"
#         },
#         {
#             "submittedAt": 1685622140006,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "providiuskatunzi@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Providius",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "id_number",
#                     "value": "2022/0643",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Ilazo",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Dodoma",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Dodoma",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Tanzania",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0753478270",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_terms_and_conditions_check",
#                     "value": "true",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20course&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-124723537&hsa_kw=cyber%20course&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIs5ytwYai_wIVIopoCR06uQfJEAEYASAAEgKyePD_BwE"
#         },
#         {
#             "submittedAt": 1685585850330,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "sifasina2008@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Sificha Sinara Yunkura",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Hawassa , Ethiopia",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Hawassa",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Sidama",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Ethiopia",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0913884295",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "company",
#                     "value": "Sidama regional state supreme court",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20course&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-124723537&hsa_kw=cyber%20course&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIgsvhrP-g_wIVF-vtCh3ANAZsEAAYASAAEgIj3PD_BwE"
#         },
#         {
#             "submittedAt": 1685562934771,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "ongagaobiero@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Ongaga Obiero",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "address",
#                     "value": "Nairobi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "city",
#                     "value": "Nairobi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "state",
#                     "value": "Nairobi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Kenya",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0702815412",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "CCSP-Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20security&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-14868266&hsa_kw=cyber%20security&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIiP3jg6qg_wIV0cztCh3Qrg7JEAAYASAAEgKbyPD_BwE"
#         },
#         {
#             "submittedAt": 1685508679611,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "vincentndiritu0@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Vincent ndiritu",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "country",
#                     "value": "Kenya",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0769909436",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "Introduction to Cyber Security",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "ecommerce_customer_currency_dropdown",
#                     "value": "US Dollar",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20course&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-124723537&hsa_kw=cyber%20course&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIkMHo6uCe_wIVStPVCh2Btwc5EAEYASAAEgKfY_D_BwE"
#         },
#         {
#             "submittedAt": 1685466113102,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "hamisareye143@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Khadar ahmed jama",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "252634410786",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20security&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-14868266&hsa_kw=cyber%20security&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAjwvdajBhBEEiwAeMh1U5Y8zLp630WC2oyEKoM2dlaojrkIWzKk8Ji5JApHmoT-yAUgWWJLzRoCaioQAvD_BwE"
#         },
#         {
#             "submittedAt": 1685451298482,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "charlesandresaintvil@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Saint-vil Charles-Andr\u00e9",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "509-35650961",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20security%20and%20hacking&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=g&hsa_tgt=kwd-86415059336&hsa_kw=cyber%20security%20and%20hacking&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAjwvdajBhBEEiwAeMh1U-IgI05hfht3KC8y7tpXiAvxa1if4B_PoGu7Hf0AhvJMi4B_ZrmOMxoCkukQAvD_BwE"
#         },
#         {
#             "submittedAt": 1685448007223,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "wwwjamesmwape2023@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "James Mwape",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+10966921787",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "CCSP-Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20security%20courses&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60917868&hsa_kw=it%20security%20courses&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI6ZDvx_6c_wIVbAcGAB2ZzgpcEAEYASAAEgKD3fD_BwE"
#         },
#         {
#             "submittedAt": 1685440418891,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "mulaudzithomphoevens@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Thompho Evens Mulaudzi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0767209695",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/software-development-courses"
#         },
#         {
#             "submittedAt": 1685437478314,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "maruhipaul@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Paul Maruhi",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+254720466266",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "Certified Cloud Security Professional",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI4en9xtec_wIVSdvVCh3V1QqVEAEYAiAAEgL4kPD_BwE"
#         },
#         {
#             "submittedAt": 1685430504649,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "johnnydavaik@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Jacob Johnn",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "67570806713",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_list",
#                     "value": "CompTIA Network+",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20security%20courses&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60917868&hsa_kw=it%20security%20courses&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIuOzL97yc_wIVehKzAB28IAHFEAEYAiAAEgIeOfD_BwE"
#         },
#         {
#             "submittedAt": 1685430157636,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "ngomazawadi0@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Zawadi ngoma",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+260964511936",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIu9e0rryc_wIVS7rVCh07WAguEAAYASAAEgLlAvD_BwE"
#         },
#         {
#             "submittedAt": 1685424711796,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "twekhomba@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Timothy Wekhomba muchimuti",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "0798417874",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIkuDIsKec_wIVyPftCh0iPwjdEAAYASAAEgJL-fD_BwE"
#         },
#         {
#             "submittedAt": 1685422553063,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "abdulmajidhussein001@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Abdimajid Hussein",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+254746333898",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=g&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=Cj0KCQjwmtGjBhDhARIsAEqfDEcVD_oq4v5VTgot9fJWG1j_pEKxGlRhM-XC970qGRR9iCv5ecCB-4QaAjI1EALw_wcB"
#         },
#         {
#             "submittedAt": 1685421782678,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "geofreyogachi221@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Geofrey Nyangara",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+10758780913",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "please_select_a_cybersecurity_learning_path",
#                     "value": "Cybersecurity Expert",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI6sL-z5yc_wIVFNntCh3ULwxZEAEYASAAEgLoT_D_BwE"
#         },
#         {
#             "submittedAt": 1685418158116,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "rinchen_pema@education.gov.bt",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Pema Rinchen",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "17995981",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Learning Path",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20cyber%20security%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60934965634&hsa_kw=it%20cyber%20security%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI74jDxo-c_wIVRA4rCh08UATrEAEYAiAAEgK3WvD_BwE"
#         },
#         {
#             "submittedAt": 1685410246785,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "haali5536@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Habib. Mughal",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "03139367595",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "OSL",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20security%20courses&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60917868&hsa_kw=it%20security%20courses&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI84XR9_Gb_wIVC8h3Ch1iyADIEAAYAiAAEgI0__D_BwE"
#         },
#         {
#             "submittedAt": 1685404472502,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "muyengalucky057@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Lucky Muyenga",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "+264812333255",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "CompTIA Security+ 601",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=it%20security%20courses&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-60917868&hsa_kw=it%20security%20courses&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMI-r-Mvtyb_wIVGdHtCh1VQwtMEAAYASAAEgJLufD_BwE"
#         },
#         {
#             "submittedAt": 1685383376632,
#             "values": [
#                 {
#                     "name": "email",
#                     "value": "gunslayer@gmail.com",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "full_name",
#                     "value": "Aj max",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "phone",
#                     "value": "75670807",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "course_package_options",
#                     "value": "Online Content + Training Labs",
#                     "objectTypeId": "0-1"
#                 },
#                 {
#                     "name": "cybersecurity_osl_only_course_list",
#                     "value": "Introduction to Cyber Security",
#                     "objectTypeId": "0-1"
#                 }
#             ],
#             "pageUrl": "https://academy.deviare.africa/en-za/cybersecurity_courses?utm_campaign=eCommerce_Leads_Campaign&utm_source=ppc&utm_medium=Search&utm_term=eCommerce%20Cybersecurity%20Paid%20Ad&utm_content=eCommerce%20Cybersecurity%20Paid%20Google%20Search&utm_term=cyber%20training&utm_campaign=eCommerce_Leads_Campaign&utm_source=adwords&utm_medium=ppc&hsa_acc=5967966482&hsa_cam=20219890471&hsa_grp=149734209596&hsa_ad=660357825824&hsa_src=s&hsa_tgt=kwd-13774470&hsa_kw=cyber%20training&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=EAIaIQobChMIkvD5142b_wIVkrLVCh0xlAh7EAAYASAAEgIXDfD_BwE"
#         }
#     ],
#     "paging": {
#         "next": {
#             "after": "Y2FmMzFhNzctZTM1NC00ZTFiLWExMTUtNmYyMGE1NjFmNTM3XzE2ODUzODMzNzY2MzI",
#             "link": "?after=Y2FmMzFhNzctZTM1NC00ZTFiLWExMTUtNmYyMGE1NjFmNTM3XzE2ODUzODMzNzY2MzI&limit=30"
#         }
#     }
# }

# %%
def capitalize_full_name(full_name):
    return full_name.title()

# %%
def format_submission(submission):
    submitted_at = submission['submittedAt']
    values = submission['values']
    
    contact_name = ''
    company = ''
    phone_number = ''
    email = ''
    customer_type = ''
    desired_course_package = ''
    desired_course = ''
    preferred_currency = ''
    linkedin_profile = ''
    city = ''
    country = ''
    
    for value in values:
        name = value['name']
        value = value['value']
        
        if name == 'full_name':
            contact_name = capitalize_full_name(value)
        elif name == 'company':
            company = value
        elif name == 'phone':
            phone_number = value
        elif name == 'email':
            email = value
        elif name == 'customer_type':
            customer_type = value
        elif name == 'desired_course_package':
            desired_course_package = value
        elif name == 'desired_course':
            desired_course = value
        elif name == 'preferred_currency':
            preferred_currency = value
        elif name == 'linkedin_profile':
            linkedin_profile = value
        elif name == 'city':
            city = value
        elif name == 'country':
            country = value
    
    formatted_submission = f"{submitted_at}\t{contact_name}\t{company}\t{phone_number}\t{email}\t{customer_type}\t{desired_course_package}\t{desired_course}\t{preferred_currency}\t{linkedin_profile}\t{city}\t{country}"
    return formatted_submission

# %%
def convert_submissions(submissions):
    converted_submissions = []
    
    for submission in submissions:
        formatted_submission = format_submission(submission)
        converted_submissions.append(formatted_submission)
    
    return converted_submissions
